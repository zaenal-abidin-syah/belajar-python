# %% [markdown]
# # Klasifikasi Cardiovascular dengan menggunakan metode Support Vector Machine

# %% [markdown]
# ## Import Library yang diperlukan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pickle
from imblearn.over_sampling import RandomOverSampler
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from scipy.stats import pearsonr, spearmanr

# %% [markdown]
# ## Load Datasets

# %%
cardio = pd.read_csv("cardiovascular.csv")
cardio
# Out:
#        Unnamed: 0       id      age  gender  height  weight  ap_hi  ap_lo  \
# 0               0      0.0  18393.0       1   168.0    62.0  110.0   80.0
# 1               1      1.0  20228.0       0   156.0    85.0  140.0   90.0
# 2               2      2.0  18857.0       0   165.0    64.0  130.0   70.0
# 3               3      3.0  17623.0       1   169.0    82.0  150.0  100.0
# 4               4      4.0  17474.0       0   156.0    56.0  100.0   60.0
# ...           ...      ...      ...     ...     ...     ...    ...    ...
# 69995       69995  99993.0  19240.0       1   168.0    76.0  120.0   80.0
# 69996       69996  99995.0  22601.0       0   158.0   126.0  140.0   90.0
# 69997       69997  99996.0  19066.0       1   183.0   105.0  180.0   90.0
# 69998       69998  99998.0  22431.0       0   163.0    72.0  135.0   80.0
# 69999       69999  99999.0  20540.0       0   170.0    72.0  120.0   80.0
#
#        cholesterol  gluc  smoke  alco  active  cardio
# 0                0     0      0     0       1       0
# 1                2     0      0     0       1       1
# 2                2     0      0     0       0       1
# 3                0     0      0     0       1       1
# 4                0     0      0     0       0       0
# ...            ...   ...    ...   ...     ...     ...
# 69995            0     0      1     0       1       0
# 69996            1     1      0     0       1       1
# 69997            2     0      0     1       0       1
# 69998            0     1      0     0       0       1
# 69999            1     0      0     0       1       0
#
# [70000 rows x 14 columns]

# %%
## ubah satuan umur ke tahun
def ageKategori(umur):
    umur = umur // 356
    if umur < 40:
        umur = 0
    elif umur < 50:
        umur = 1
    elif umur < 60:
        umur = 2
    elif umur < 70:
        umur = 3
    return umur
        
# cardio["age_year"] = cardio['age'] // 356
# cardio = cardio.drop(columns='age')
cardio["age"] = cardio["age"].apply(ageKategori)
cardio.head()
# Out:
#    Unnamed: 0   id  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0           0  0.0       1   168.0    62.0  110.0   80.0            0     0
# 1           1  1.0       0   156.0    85.0  140.0   90.0            2     0
# 2           2  2.0       0   165.0    64.0  130.0   70.0            2     0
# 3           3  3.0       1   169.0    82.0  150.0  100.0            0     0
# 4           4  4.0       0   156.0    56.0  100.0   60.0            0     0
#
#    smoke  alco  active  cardio  age_year
# 0      0     0       1       0      51.0
# 1      0     0       1       1      56.0
# 2      0     0       0       1      52.0
# 3      0     0       1       1      49.0
# 4      0     0       0       0      49.0

# %% [markdown]
# ## Business Understanding
#
# Tujuan :
# membangun model prediksi yang mampu mengidentifikasi keberadaan penyakit kardiovaskular (CVD) pada pasien berdasarkan berbagai faktor, termasuk data obyektif, hasil pemeriksaan medis, dan perilaku yang dilaporkan oleh pasien. Deteksi dini CVD dapat menghasilkan intervensi yang tepat waktu, meningkatkan hasil kesehatan pasien, dan mengurangi biaya perawatan kesehatan.

# %% [markdown]
# ### Data Understanding
#
# dataset cardiovascular ini merupakan data klasifikasi untuk memprediksi status cardio atau penyakit jantung pada pasien berdasarkan 11 fitur yang datanya diambil dari 70.000 pasien. fitur di dapatkan dari informasi faktual (age, height, weight, dan gender), hasil pemeriksaan medis(tekanan darah sistolik, tekanan darah diastolik, kolestrol, dan glukosa), dan informasi yang diberikan pasien(smoke, alcohol, aktivitas fisik).
#
# #### Deskripsi Data:
#
# Dataset ini berisi berbagai fitur yang dapat dikelompokkan sebagai berikut: (tambahkan tipe data, ukuran datanya, detailnya)
#
# ##### Fitur Obyektif ( informasi faktual ):
#
# Age
#
#     Tipe Data: Integer
#     Deskripsi: Usia pasien dalam satuan hari. Fitur ini dapat dikonversi ke tahun untuk memudahkan interpretasi dan analisis.
#
# Height
#
#     Tipe Data: Integer
#     Deskripsi: Tinggi badan pasien yang diukur dalam sentimeter.
#
# Weight
#
#     Tipe Data: Float
#     Deskripsi: Berat badan pasien dalam kilogram. Fitur ini memiliki tipe data float untuk mengakomodasi nilai desimal yang mungkin muncul.
#
# Gender
#
#     Tipe Data: Kategori
#     Deskripsi: Menunjukkan jenis kelamin pasien, umumnya dikodekan sebagai 1 untuk laki-laki dan 2 untuk perempuan.
#
#
# ##### Fitur Pemeriksaan (hasil pemeriksaan medis):
#
# Tekanan darah sistolik (ap_hi)
#
#     Tipe Data: Integer
#     Deskripsi: Tekanan darah sistolik, yaitu tekanan maksimum di arteri saat jantung berdetak.
#
# Tekanan darah diastolik (ap_lo)
#
#     Tipe Data: Integer
#     Deskripsi: Tekanan darah diastolik, yaitu tekanan dalam arteri antara detak jantung.
#
# Kolestrol
#
#     Tipe Data: Kategori
#     Deskripsi: Kategori kadar kolesterol pasien, dengan tiga tingkat—1 untuk normal, 2 untuk di atas normal, dan 3 untuk jauh di atas normal.
#
# Glukosa
#
#     Tipe Data: Kategori
#     Deskripsi: Kategori kadar glukosa darah pasien, dengan tiga tingkat—1 untuk normal, 2 untuk di atas normal, dan 3 untuk jauh di atas normal.
#
#
# ##### Fitur Subyektif ( informasi yang diberikan pasien ):
#
# Smoking (smoke)
#
#     Tipe Data: Binary
#     Deskripsi: Variabel biner yang menunjukkan apakah pasien merokok atau tidak, biasanya dikodekan sebagai 1 untuk ya dan 0 untuk tidak.
#
# Alcohol Intake (alco)
#
#     Tipe Data: Binary
#     Deskripsi: Variabel biner yang menunjukkan apakah pasien mengonsumsi alkohol, dengan kode 1 untuk ya dan 0 untuk tidak.
#
# Physical Activity (active)
#
#     Tipe Data: Binary
#     Deskripsi: Variabel biner yang menunjukkan apakah pasien aktif secara fisik, dengan kode 1 untuk ya dan 0 untuk tidak.
#
#
# Variabel Target:
#
# Cardio
#
#     Tipe Data: Binary
#     Deskripsi: Variabel target yang menunjukkan keberadaan penyakit kardiovaskular pada pasien. Dikodekan sebagai 1 jika ada penyakit dan 0 jika tidak ada.

# %%
descriptive_stats = cardio.describe()
print("statistik deskriptif")
print(descriptive_stats)
# Out:
# statistik deskriptif
#          Unnamed: 0            id        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   34999.500000  49972.419900      0.349571    164.359229     74.205690
# std    20207.403759  28851.302323      0.476838      8.210126     14.395757
# min        0.000000      0.000000      0.000000     55.000000     10.000000
# 25%    17499.750000  25006.750000      0.000000    159.000000     65.000000
# 50%    34999.500000  50001.500000      0.000000    165.000000     72.000000
# 75%    52499.250000  74889.250000      1.000000    170.000000     82.000000
# max    69999.000000  99999.000000      1.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      0.366871      0.226457      0.088129
# std      154.011419    188.472530      0.680250      0.572270      0.283484
# min     -150.000000    -70.000000      0.000000      0.000000      0.000000
# 25%      120.000000     80.000000      0.000000      0.000000      0.000000
# 50%      120.000000     80.000000      0.000000      0.000000      0.000000
# 75%      140.000000     90.000000      1.000000      0.000000      0.000000
# max    16020.000000  11000.000000      2.000000      2.000000      1.000000
#
#                alco        active        cardio      age_year
# count  70000.000000  70000.000000  70000.000000  70000.000000
# mean       0.053771      0.803729      0.499700     54.188529
# std        0.225568      0.397179      0.500003      6.936058
# min        0.000000      0.000000      0.000000     30.000000
# 25%        0.000000      1.000000      0.000000     49.000000
# 50%        0.000000      1.000000      0.000000     55.000000
# 75%        0.000000      1.000000      1.000000     59.000000
# max        1.000000      1.000000      1.000000     66.000000

# %%
label_counts = cardio["cardio"].value_counts()
label_counts
# Out:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='cardio', data=cardio)
plt.title("distribusi Cardiovascular")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=cardio, x="age_year", hue="cardio", kde=True, bins=20)
plt.title("Distribusi umur berdasarkan kardio")
plt.show()

# %%
pearson_corr, p_value = pearsonr(cardio["age_year"], cardio["cardio"])
spearman_corr, _ = spearmanr(cardio["age_year"], cardio["cardio"])

sns.lmplot(x="age_year", y="cardio", data=cardio, ci=None)
plt.title(f"Korelasi Pearson : {pearson_corr:.2f}, Korelasi Spearman : {spearman_corr:.2f}")
plt.xlabel("age_year")
plt.ylabel("cardio")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=cardio, x="height", hue="cardio", kde=True, bins=20)
plt.title("Distribusi tinggi berdasarkan kardio")
plt.show()

# %%
pearson_corr, p_value = pearsonr(cardio["height"], cardio["cardio"])
spearman_corr, _ = spearmanr(cardio["height"], cardio["cardio"])

sns.lmplot(x="height", y="cardio", data=cardio, ci=None)
plt.title(f"Korelasi Pearson : {pearson_corr:.2f}, Korelasi Spearman : {spearman_corr:.2f}")
plt.xlabel("height")
plt.ylabel("cardio")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=cardio, x="weight", hue="cardio", kde=True, bins=20)
plt.title("Distribusi weight berdasarkan kardio")
plt.show()

# %%
pearson_corr, p_value = pearsonr(cardio["weight"], cardio["cardio"])
spearman_corr, _ = spearmanr(cardio["weight"], cardio["cardio"])

sns.lmplot(x="weight", y="cardio", data=cardio, ci=None)
plt.title(f"Korelasi Pearson : {pearson_corr:.2f}, Korelasi Spearman : {spearman_corr:.2f}")
plt.xlabel("weight")
plt.ylabel("cardio")
plt.show()

# %%
correlations = []

for data in cardio:
    print(data)
    if data != "cardio":  # Hindari menghitung korelasi variabel dengan dirinya sendiri
        pearson_corr, _ = pearsonr(cardio[data], cardio["cardio"])
        spearman_corr, _ = spearmanr(cardio[data], cardio["cardio"])
        
        # Tambahkan hasil ke dalam list
        correlations.append({"variable": data, "pearson": pearson_corr, "spearman": spearman_corr})
    # pearson_corr, p_value = pearsonr(cardio[data], cardio["cardio"])
    # spearman_corr, _ = spearmanr(cardio[data], cardio["cardio"])
    
    sns.lmplot(x=data, y="cardio", data=cardio, ci=None)
    plt.title(f"Korelasi Pearson : {pearson_corr:.2f}, Korelasi Spearman : {spearman_corr:.2f}")
    plt.xlabel(data)
    plt.ylabel("cardio")
    plt.show()

print("Hasil Korelasi (diurutkan berdasarkan Pearson):")
for corr in sorted_correlations:
    print(f"Variabel: {corr['variable']}, Pearson: {corr['pearson']:.2f}, Spearman: {corr['spearman']:.2f}")
# Out:
# Unnamed: 0
# id
# age
# gender
# height
# weight
# ap_hi
# ap_lo
# cholesterol
# gluc
# smoke
# alco
# active
# cardio
# age_year
# Hasil Korelasi (diurutkan berdasarkan Pearson):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 21
#      18     plt.show()
#      20 print("Hasil Korelasi (diurutkan berdasarkan Pearson):")
# ---> 21 for corr in sorted_correlations:
#      22     print(f"Variabel: {corr['variable']}, Pearson: {corr['pearson']:.2f}, Spearman: {corr['spearman']:.2f}")
#
# NameError: name 'sorted_correlations' is not defined

# %%
# korelasi antar fitur using heatmap
correlations = []

for i in cardio:
    for j in cardio:
        if i != "cardio" and j != "cardio" and i!=j:  # Hindari menghitung korelasi variabel dengan dirinya sendiri
            pearson_corr, _ = pearsonr(cardio[i], cardio[j])
            spearman_corr, _ = spearmanr(cardio[i], cardio[j])
            
            # Tambahkan hasil ke dalam list
            correlations.append({"variable": i, "variable2" : j, "pearson": pearson_corr, "spearman": spearman_corr})
    # pearson_corr, p_value = pearsonr(cardio[data], cardio["cardio"])
    # spearman_corr, _ = spearmanr(cardio[data], cardio["cardio"])
    
    # sns.lmplot(x=data, y="cardio", data=cardio, ci=None)
    # plt.title(f"Korelasi Pearson : {pearson_corr:.2f}, Korelasi Spearman : {spearman_corr:.2f}")
    # plt.xlabel(data)
    # plt.ylabel("cardio")
    # plt.show()

sorted_correlations = sorted(correlations, key=lambda x: abs(x["pearson"]), reverse=True)

print("Hasil Korelasi (diurutkan berdasarkan Pearson):")
for corr in sorted_correlations:
    print(f"Variabel: {corr['variable']}, {corr['variable2']}, Pearson: {corr['pearson']:.2f}, Spearman: {corr['spearman']:.2f}")
# Out:
# Hasil Korelasi (diurutkan berdasarkan Pearson):
# Variabel: Unnamed: 0, id, Pearson: 1.00, Spearman: 1.00
# Variabel: id, Unnamed: 0, Pearson: 1.00, Spearman: 1.00
# Variabel: age, age_year, Pearson: 1.00, Spearman: 1.00
# Variabel: age_year, age, Pearson: 1.00, Spearman: 1.00
# Variabel: gender, height, Pearson: 0.50, Spearman: 0.53
# Variabel: height, gender, Pearson: 0.50, Spearman: 0.53
# Variabel: cholesterol, gluc, Pearson: 0.45, Spearman: 0.41
# Variabel: gluc, cholesterol, Pearson: 0.45, Spearman: 0.41
# Variabel: smoke, alco, Pearson: 0.34, Spearman: 0.34
# Variabel: alco, smoke, Pearson: 0.34, Spearman: 0.34
# Variabel: gender, smoke, Pearson: 0.34, Spearman: 0.34
# Variabel: smoke, gender, Pearson: 0.34, Spearman: 0.34
# Variabel: height, weight, Pearson: 0.29, Spearman: 0.31
# Variabel: weight, height, Pearson: 0.29, Spearman: 0.31
# Variabel: height, smoke, Pearson: 0.19, Spearman: 0.20
# Variabel: smoke, height, Pearson: 0.19, Spearman: 0.20
# Variabel: gender, alco, Pearson: 0.17, Spearman: 0.17
# Variabel: alco, gender, Pearson: 0.17, Spearman: 0.17
# Variabel: gender, weight, Pearson: 0.16, Spearman: 0.17
# Variabel: weight, gender, Pearson: 0.16, Spearman: 0.17
# Variabel: age, cholesterol, Pearson: 0.15, Spearman: 0.14
# Variabel: cholesterol, age, Pearson: 0.15, Spearman: 0.14
# Variabel: cholesterol, age_year, Pearson: 0.15, Spearman: 0.14
# Variabel: age_year, cholesterol, Pearson: 0.15, Spearman: 0.14
# Variabel: weight, cholesterol, Pearson: 0.14, Spearman: 0.14
# Variabel: cholesterol, weight, Pearson: 0.14, Spearman: 0.14
# Variabel: weight, gluc, Pearson: 0.11, Spearman: 0.11
# Variabel: gluc, weight, Pearson: 0.11, Spearman: 0.11
# Variabel: age, gluc, Pearson: 0.10, Spearman: 0.09
# Variabel: gluc, age, Pearson: 0.10, Spearman: 0.09
# Variabel: gluc, age_year, Pearson: 0.10, Spearman: 0.09
# Variabel: age_year, gluc, Pearson: 0.10, Spearman: 0.09
# Variabel: height, alco, Pearson: 0.09, Spearman: 0.10
# Variabel: alco, height, Pearson: 0.09, Spearman: 0.10
# Variabel: height, age_year, Pearson: -0.08, Spearman: -0.08
# Variabel: age_year, height, Pearson: -0.08, Spearman: -0.08
# Variabel: age, height, Pearson: -0.08, Spearman: -0.08
# Variabel: height, age, Pearson: -0.08, Spearman: -0.08
# Variabel: weight, smoke, Pearson: 0.07, Spearman: 0.07
# Variabel: smoke, weight, Pearson: 0.07, Spearman: 0.07
# Variabel: weight, alco, Pearson: 0.07, Spearman: 0.07
# Variabel: alco, weight, Pearson: 0.07, Spearman: 0.07
# Variabel: age, weight, Pearson: 0.05, Spearman: 0.06
# Variabel: weight, age, Pearson: 0.05, Spearman: 0.06
# Variabel: weight, age_year, Pearson: 0.05, Spearman: 0.06
# Variabel: age_year, weight, Pearson: 0.05, Spearman: 0.06
# Variabel: height, cholesterol, Pearson: -0.05, Spearman: -0.06
# Variabel: cholesterol, height, Pearson: -0.05, Spearman: -0.06
# Variabel: smoke, age_year, Pearson: -0.05, Spearman: -0.05
# Variabel: age_year, smoke, Pearson: -0.05, Spearman: -0.05
# Variabel: age, smoke, Pearson: -0.05, Spearman: -0.05
# Variabel: smoke, age, Pearson: -0.05, Spearman: -0.05
# Variabel: weight, ap_lo, Pearson: 0.04, Spearman: 0.25
# Variabel: ap_lo, weight, Pearson: 0.04, Spearman: 0.25
# Variabel: gender, cholesterol, Pearson: -0.04, Spearman: -0.04
# Variabel: cholesterol, gender, Pearson: -0.04, Spearman: -0.04
# Variabel: cholesterol, alco, Pearson: 0.04, Spearman: 0.04
# Variabel: alco, cholesterol, Pearson: 0.04, Spearman: 0.04
# Variabel: weight, ap_hi, Pearson: 0.03, Spearman: 0.28
# Variabel: ap_hi, weight, Pearson: 0.03, Spearman: 0.28
# Variabel: alco, age_year, Pearson: -0.03, Spearman: -0.03
# Variabel: age_year, alco, Pearson: -0.03, Spearman: -0.03
# Variabel: age, alco, Pearson: -0.03, Spearman: -0.03
# Variabel: alco, age, Pearson: -0.03, Spearman: -0.03
# Variabel: smoke, active, Pearson: 0.03, Spearman: 0.03
# Variabel: active, smoke, Pearson: 0.03, Spearman: 0.03
# Variabel: alco, active, Pearson: 0.03, Spearman: 0.03
# Variabel: active, alco, Pearson: 0.03, Spearman: 0.03
# Variabel: ap_lo, cholesterol, Pearson: 0.02, Spearman: 0.17
# Variabel: cholesterol, ap_lo, Pearson: 0.02, Spearman: 0.17
# Variabel: ap_hi, cholesterol, Pearson: 0.02, Spearman: 0.21
# Variabel: cholesterol, ap_hi, Pearson: 0.02, Spearman: 0.21
# Variabel: age, gender, Pearson: -0.02, Spearman: -0.02
# Variabel: gender, age, Pearson: -0.02, Spearman: -0.02
# Variabel: gender, age_year, Pearson: -0.02, Spearman: -0.02
# Variabel: age_year, gender, Pearson: -0.02, Spearman: -0.02
# Variabel: ap_hi, age_year, Pearson: 0.02, Spearman: 0.22
# Variabel: age_year, ap_hi, Pearson: 0.02, Spearman: 0.22
# Variabel: age, ap_hi, Pearson: 0.02, Spearman: 0.22
# Variabel: ap_hi, age, Pearson: 0.02, Spearman: 0.22
# Variabel: gender, gluc, Pearson: -0.02, Spearman: -0.02
# Variabel: gluc, gender, Pearson: -0.02, Spearman: -0.02
# Variabel: height, gluc, Pearson: -0.02, Spearman: -0.02
# Variabel: gluc, height, Pearson: -0.02, Spearman: -0.02
# Variabel: age, ap_lo, Pearson: 0.02, Spearman: 0.16
# Variabel: ap_lo, age, Pearson: 0.02, Spearman: 0.16
# Variabel: ap_lo, age_year, Pearson: 0.02, Spearman: 0.16
# Variabel: age_year, ap_lo, Pearson: 0.02, Spearman: 0.16
# Variabel: weight, active, Pearson: -0.02, Spearman: -0.01
# Variabel: active, weight, Pearson: -0.02, Spearman: -0.01
# Variabel: ap_hi, ap_lo, Pearson: 0.02, Spearman: 0.74
# Variabel: ap_lo, ap_hi, Pearson: 0.02, Spearman: 0.74
# Variabel: gender, ap_lo, Pearson: 0.02, Spearman: 0.07
# Variabel: ap_lo, gender, Pearson: 0.02, Spearman: 0.07
# Variabel: ap_hi, gluc, Pearson: 0.01, Spearman: 0.11
# Variabel: gluc, ap_hi, Pearson: 0.01, Spearman: 0.11
# Variabel: gluc, alco, Pearson: 0.01, Spearman: 0.02
# Variabel: alco, gluc, Pearson: 0.01, Spearman: 0.02
# Variabel: ap_lo, gluc, Pearson: 0.01, Spearman: 0.08
# Variabel: gluc, ap_lo, Pearson: 0.01, Spearman: 0.08
# Variabel: ap_lo, alco, Pearson: 0.01, Spearman: 0.04
# Variabel: alco, ap_lo, Pearson: 0.01, Spearman: 0.04
# Variabel: cholesterol, smoke, Pearson: 0.01, Spearman: 0.02
# Variabel: smoke, cholesterol, Pearson: 0.01, Spearman: 0.02
# Variabel: age, active, Pearson: -0.01, Spearman: -0.01
# Variabel: active, age, Pearson: -0.01, Spearman: -0.01
# Variabel: cholesterol, active, Pearson: 0.01, Spearman: 0.01
# Variabel: active, cholesterol, Pearson: 0.01, Spearman: 0.01
# Variabel: active, age_year, Pearson: -0.01, Spearman: -0.01
# Variabel: age_year, active, Pearson: -0.01, Spearman: -0.01
# Variabel: gluc, active, Pearson: -0.01, Spearman: -0.01
# Variabel: active, gluc, Pearson: -0.01, Spearman: -0.01
# Variabel: height, active, Pearson: -0.01, Spearman: -0.01
# Variabel: active, height, Pearson: -0.01, Spearman: -0.01
# Variabel: height, ap_lo, Pearson: 0.01, Spearman: 0.03
# Variabel: ap_lo, height, Pearson: 0.01, Spearman: 0.03
# Variabel: Unnamed: 0, cholesterol, Pearson: 0.01, Spearman: 0.01
# Variabel: cholesterol, Unnamed: 0, Pearson: 0.01, Spearman: 0.01
# Variabel: id, cholesterol, Pearson: 0.01, Spearman: 0.01
# Variabel: cholesterol, id, Pearson: 0.01, Spearman: 0.01
# Variabel: gender, ap_hi, Pearson: 0.01, Spearman: 0.06
# Variabel: ap_hi, gender, Pearson: 0.01, Spearman: 0.06
# Variabel: gender, active, Pearson: 0.01, Spearman: 0.01
# Variabel: active, gender, Pearson: 0.01, Spearman: 0.01
# Variabel: height, ap_hi, Pearson: 0.01, Spearman: 0.02
# Variabel: ap_hi, height, Pearson: 0.01, Spearman: 0.02
# Variabel: ap_lo, smoke, Pearson: 0.01, Spearman: 0.03
# Variabel: smoke, ap_lo, Pearson: 0.01, Spearman: 0.03
# Variabel: ap_lo, active, Pearson: 0.00, Spearman: 0.00
# Variabel: active, ap_lo, Pearson: 0.00, Spearman: 0.00
# Variabel: gluc, smoke, Pearson: -0.00, Spearman: 0.00
# Variabel: smoke, gluc, Pearson: -0.00, Spearman: 0.00
# Variabel: Unnamed: 0, active, Pearson: 0.00, Spearman: 0.00
# Variabel: active, Unnamed: 0, Pearson: 0.00, Spearman: 0.00
# Variabel: id, active, Pearson: 0.00, Spearman: 0.00
# Variabel: active, id, Pearson: 0.00, Spearman: 0.00
# Variabel: id, smoke, Pearson: -0.00, Spearman: -0.00
# Variabel: smoke, id, Pearson: -0.00, Spearman: -0.00
# Variabel: Unnamed: 0, smoke, Pearson: -0.00, Spearman: -0.00
# Variabel: smoke, Unnamed: 0, Pearson: -0.00, Spearman: -0.00
# Variabel: Unnamed: 0, gender, Pearson: 0.00, Spearman: 0.00
# Variabel: gender, Unnamed: 0, Pearson: 0.00, Spearman: 0.00
# Variabel: id, gender, Pearson: 0.00, Spearman: 0.00
# Variabel: gender, id, Pearson: 0.00, Spearman: 0.00
# Variabel: id, age, Pearson: 0.00, Spearman: 0.00
# Variabel: age, id, Pearson: 0.00, Spearman: 0.00
# Variabel: Unnamed: 0, age, Pearson: 0.00, Spearman: 0.00
# Variabel: age, Unnamed: 0, Pearson: 0.00, Spearman: 0.00
# Variabel: id, age_year, Pearson: 0.00, Spearman: 0.00
# Variabel: age_year, id, Pearson: 0.00, Spearman: 0.00
# Variabel: Unnamed: 0, age_year, Pearson: 0.00, Spearman: 0.00
# Variabel: age_year, Unnamed: 0, Pearson: 0.00, Spearman: 0.00
# Variabel: Unnamed: 0, ap_hi, Pearson: 0.00, Spearman: 0.00
# Variabel: ap_hi, Unnamed: 0, Pearson: 0.00, Spearman: 0.00
# Variabel: id, ap_hi, Pearson: 0.00, Spearman: 0.00
# Variabel: ap_hi, id, Pearson: 0.00, Spearman: 0.00
# Variabel: Unnamed: 0, height, Pearson: -0.00, Spearman: -0.00
# Variabel: height, Unnamed: 0, Pearson: -0.00, Spearman: -0.00
# Variabel: id, height, Pearson: -0.00, Spearman: -0.00
# Variabel: height, id, Pearson: -0.00, Spearman: -0.00
# Variabel: Unnamed: 0, ap_lo, Pearson: -0.00, Spearman: -0.00
# Variabel: ap_lo, Unnamed: 0, Pearson: -0.00, Spearman: -0.00
# Variabel: id, ap_lo, Pearson: -0.00, Spearman: -0.00
# Variabel: ap_lo, id, Pearson: -0.00, Spearman: -0.00
# Variabel: Unnamed: 0, gluc, Pearson: 0.00, Spearman: 0.00
# Variabel: gluc, Unnamed: 0, Pearson: 0.00, Spearman: 0.00
# Variabel: id, gluc, Pearson: 0.00, Spearman: 0.00
# Variabel: gluc, id, Pearson: 0.00, Spearman: 0.00
# Variabel: id, weight, Pearson: -0.00, Spearman: -0.00
# Variabel: weight, id, Pearson: -0.00, Spearman: -0.00
# Variabel: Unnamed: 0, weight, Pearson: -0.00, Spearman: -0.00
# Variabel: weight, Unnamed: 0, Pearson: -0.00, Spearman: -0.00
# Variabel: ap_hi, alco, Pearson: 0.00, Spearman: 0.03
# Variabel: alco, ap_hi, Pearson: 0.00, Spearman: 0.03
# Variabel: Unnamed: 0, alco, Pearson: 0.00, Spearman: 0.00
# Variabel: alco, Unnamed: 0, Pearson: 0.00, Spearman: 0.00
# Variabel: id, alco, Pearson: 0.00, Spearman: 0.00
# Variabel: alco, id, Pearson: 0.00, Spearman: 0.00
# Variabel: ap_hi, smoke, Pearson: -0.00, Spearman: 0.03
# Variabel: smoke, ap_hi, Pearson: -0.00, Spearman: 0.03
# Variabel: ap_hi, active, Pearson: -0.00, Spearman: -0.00
# Variabel: active, ap_hi, Pearson: -0.00, Spearman: -0.00

# %% [markdown]
# ## Pengecekan Nilai NaN

# %%
nan_info = cardio.isnull().sum()
nan_columns = nan_info[nan_info > 0]
print("fitur dengan nilai NaN")
nan_columns
# Out:
# fitur dengan nilai NaN
# Series([], dtype: int64)

# %% [markdown]
# ## penghapusan fitur yang tidak relevan

# %%
cardio = cardio.drop(["id", "Unnamed: 0", "age"], axis="columns")

# %%
cardio.head()
# Out:
#    gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0       1   168.0    62.0  110.0   80.0            0     0      0     0
# 1       0   156.0    85.0  140.0   90.0            2     0      0     0
# 2       0   165.0    64.0  130.0   70.0            2     0      0     0
# 3       1   169.0    82.0  150.0  100.0            0     0      0     0
# 4       0   156.0    56.0  100.0   60.0            0     0      0     0
#
#    active  cardio  age_year
# 0       1       0      51.0
# 1       1       1      56.0
# 2       0       1      52.0
# 3       1       1      49.0
# 4       0       0      49.0

# %% [markdown]
# ## Spliting data

# %%
X = cardio.drop("cardio", axis="columns")
y = cardio['cardio']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (56000, 11)
# (14000, 11)
# (56000,)
# (14000,)

# %% [markdown]
# ## Standarisasi Z-Score

# %%
scaler = StandardScaler()
columns = ["age", "height", "weight", "ap_hi", "ap_lo"]

non_binary_columns = [ col for col in X_train.columns if col in columns]
scaler.fit(X_train[non_binary_columns])
X_train[non_binary_columns] = scaler.transform(X_train[non_binary_columns])
X_train
# fitur_scale = []

# for data in X_train.columns:
#     if X_train[data].min() < 0 or X_train[data].max() > 1:
#         fitur_scale.append(data)
# scaler.fit(X_train[fitur_scale])
# X_train[fitur_scale] = scaler.transform(X_train[fitur_scale])
# X_train
# Out:
#        gender    height    weight     ap_hi     ap_lo  cholesterol  gluc  \
# 57050       0 -1.020082 -0.087893 -0.058621 -0.086929            1     0
# 66119       1  0.928171  0.258399  0.146192  0.017852            0     0
# 2762        0 -0.898317 -0.988254 -0.195164 -0.191710            1     0
# 6182        1  0.441108  0.050624 -0.058621 -0.086929            0     0
# 35804       1  0.197576 -0.711220  0.146192 -0.034538            1     0
# ...       ...       ...       ...       ...       ...          ...   ...
# 49100       1  1.293468  0.258399 -0.058621 -0.086929            0     0
# 20609       0 -0.045956 -0.434186 -0.058621 -0.086929            0     0
# 21440       1  1.658766  0.535434 -0.058621 -0.086929            0     0
# 50057       0  0.562873  0.189141 -0.058621 -0.086929            0     0
# 5192        0  1.171703 -0.641961  0.214463 -0.034538            1     1
#
#        smoke  alco  active  age_year
# 57050      0     0       1      56.0
# 66119      1     1       1      55.0
# 2762       0     0       1      61.0
# 6182       0     0       1      55.0
# 35804      0     0       1      61.0
# ...      ...   ...     ...       ...
# 49100      0     0       1      59.0
# 20609      0     0       0      53.0
# 21440      0     0       1      50.0
# 50057      0     0       0      61.0
# 5192       0     0       1      58.0
#
# [56000 rows x 11 columns]

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=cardio, x="weight", hue="cardio", kde=True, bins=20)
plt.title("Distribusi berat berdasarkan kardio")
plt.show()

# %%
sns.lmplot(x="ap_hi", y="cardio", data=data, ci=None)
plt.title(f"Korelasi Pearson : {pearson_corr:.2f}, Korelasi Spearman : {spearman_corr:.2f}")
plt.xlabel("ap_hi")
plt.ylabel("cardio")
plt.show()

# %% [markdown]
# ## Balancing Data

# %%
print(X_train.shape)
print(y_train.shape)

# %%
ros = RandomOverSampler(random_state=1)
X_resample, y_resample = ros.fit_resample(X_train, y_train)
print(X_resample.shape)
print(y_resample.shape)

# %% [markdown]
# ## Normalisasi untuk data testing

# %%
X_test[non_binary_columns] = scaler.transform(X_test[non_binary_columns])
X_test

# %% [markdown]
# ## Modeling menggunakan SVM

# %%
svm_model = SVC(kernel="linear", C=1.0, random_state=42, class_weight="balanced")
svm_model.fit(X_resample, y_resample)

# %% [markdown]
# ## Akurasi

# %%
y_pred = svm_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
accuracy

# %% [markdown]
# ## mengukur confusion matrix

# %%
conf = confusion_matrix(y_test, y_pred)
conf

# %%
cm_display = ConfusionMatrixDisplay(confusion_matrix = conf, display_labels = [0, 1])
cm_display.plot()
plt.show()
