# %%
def selectionSort(listData):
    print('Algoritma Selection Sort konvensional')
    print('Data Awal=',listData)
    for outIter in range(len(listData)-1):
        minIndex=outIter
        for i in range(outIter+1,len(listData)):
            if listData[i]<listData[minIndex]:
                minIndex=i
        temp=listData[outIter]
        listData[outIter]=listData[minIndex]
        listData[minIndex]=temp
        print('Iterasi ke-',outIter+1,':',listData)
    print('Data Urut=',listData)

# %%
a=[10,2,5,8,1,20,7,12,4]
selectionSort(a)
# Out:
# Algoritma Selection Sort konvensional
# Data Awal= [10, 2, 5, 8, 1, 20, 7, 12, 4]
# Iterasi ke- 1 : [1, 2, 5, 8, 10, 20, 7, 12, 4]
# Iterasi ke- 2 : [1, 2, 5, 8, 10, 20, 7, 12, 4]
# Iterasi ke- 3 : [1, 2, 4, 8, 10, 20, 7, 12, 5]
# Iterasi ke- 4 : [1, 2, 4, 5, 10, 20, 7, 12, 8]
# Iterasi ke- 5 : [1, 2, 4, 5, 7, 20, 10, 12, 8]
# Iterasi ke- 6 : [1, 2, 4, 5, 7, 8, 10, 12, 20]
# Iterasi ke- 7 : [1, 2, 4, 5, 7, 8, 10, 12, 20]
# Iterasi ke- 8 : [1, 2, 4, 5, 7, 8, 10, 12, 20]
# Data Urut= [1, 2, 4, 5, 7, 8, 10, 12, 20]

# %%
a = [11, 5, 7, 13, 2, 8]
index=0
minData=a[0]
for i in range(1, len(a)):
    print(minData, '>', a[i])
    if minData > a[i]:
        minData = a[i]
        index = i
print(minData, 'index ', index)
a[index]=a[0]
a[0]=minData
print(a)
print()

minData=a[1]
index=1
for i in range(2, len(a)):
    print(minData, '>', a[i])
    print(index)
    if minData > a[i]:
        minData = a[i]
        index = i
print(minData, 'index ', index)
a[index]=a[1]
a[1]=minData
print(a)
print()

start = 2
minData=a[start]
index=start
for i in range(start+1, len(a)):
    print(minData, '>', a[i])
    print(index)
    if minData > a[i]:
        minData = a[i]
        index = i
print(minData, 'index ', index)
a[index]=a[start]
a[start]=minData
print(a)
print()

start = 3
minData=a[start]
index=start
for i in range(start+1, len(a)):
    print(minData, '>', a[i])
    print(index)
    if minData > a[i]:
        minData = a[i]
        index = i
print(minData, 'index ', index)
a[index]=a[start]
a[start]=minData
print(a)
print()
# Out:
# 11 > 5
# 5 > 7
# 5 > 13
# 5 > 2
# 2 > 8
# 2 index  4
# [2, 5, 7, 13, 11, 8]
#
# 5 > 7
# 1
# 5 > 13
# 1
# 5 > 11
# 1
# 5 > 8
# 1
# 5 index  1
# [2, 5, 7, 13, 11, 8]
#
# 7 > 13
# 2
# 7 > 11
# 2
# 7 > 8
# 2
# 7 index  2
# [2, 5, 7, 13, 11, 8]
#
# 13 > 11
# 3
# 11 > 8
# 4
# 8 index  5
# [2, 5, 7, 8, 11, 13]

# %%
a = [11, 5, 7, 13, 2, 8]
for start in range(len(a)-1):
    minData=a[start]
    index=start
    for i in range(start+1, len(a)):
        print(minData, '>', a[i])
        print(index)
        if minData > a[i]:
            minData = a[i]
            index = i
    print(minData, 'index ', index)
    a[index]=a[start]
    a[start]=minData
    print(a)
    print()
# Out:
# 11 > 5
# 0
# 5 > 7
# 1
# 5 > 13
# 1
# 5 > 2
# 1
# 2 > 8
# 4
# 2 index  4
# [2, 5, 7, 13, 11, 8]
#
# 5 > 7
# 1
# 5 > 13
# 1
# 5 > 11
# 1
# 5 > 8
# 1
# 5 index  1
# [2, 5, 7, 13, 11, 8]
#
# 7 > 13
# 2
# 7 > 11
# 2
# 7 > 8
# 2
# 7 index  2
# [2, 5, 7, 13, 11, 8]
#
# 13 > 11
# 3
# 11 > 8
# 4
# 8 index  5
# [2, 5, 7, 8, 11, 13]
#
# 11 > 13
# 4
# 11 index  4
# [2, 5, 7, 8, 11, 13]

# %%
# ascending 
data = [8, 3, 0, 11, 4, 1]
maks = data[0]
idMaks = 0
print('data awal = ',data)
for i in range(1, len(data)):
    print(maks, ' < ', data[i])
    if maks < data[i]:
        maks=data[i]
        idMaks = i
print('Nilai maks = ', maks, 'indeks = ', idMaks)
# data[-1], data[idMaks] = data[idMaks], data[-1]
data[idMaks]=data[len(data)-1]
data[len(data)-1] = maks
print(data)
# Out:
# data awal =  [8, 3, 0, 11, 4, 1]
# 8  <  3
# 8  <  0
# 8  <  11
# 11  <  4
# 11  <  1
# Nilai maks =  11 indeks =  3
# [8, 3, 0, 1, 4, 11]

# %%
# ascending 
maks = data[0]
idMaks = 0
print('data awal = ',data)
for i in range(1, len(data)-1):
    print(maks, ' < ', data[i])
    if maks < data[i]:
        maks=data[i]
        idMaks = i
print('Nilai maks = ', maks, 'indeks = ', idMaks)
# data[-1], data[idMaks] = data[idMaks], data[-1]
data[idMaks]=data[len(data)-2]
data[len(data)-2] = maks
print(data)
# Out:
# data awal =  [8, 3, 0, 1, 4, 11]
# 8  <  3
# 8  <  0
# 8  <  1
# 8  <  4
# Nilai maks =  8 indeks =  0
# [4, 3, 0, 1, 8, 11]

# %%
# ascending 
maks = data[0]
idMaks = 0
print('data awal = ',data)
for i in range(1, len(data)-2):
    print(maks, ' < ', data[i])
    if maks < data[i]:
        maks=data[i]
        idMaks = i
print('Nilai maks = ', maks, 'indeks = ', idMaks)
# data[-1], data[idMaks] = data[idMaks], data[-1]
data[idMaks]=data[len(data)-3]
data[len(data)-3] = maks
print(data)
# Out:
# data awal =  [4, 3, 0, 1, 8, 11]
# 4  <  3
# 4  <  0
# 4  <  1
# Nilai maks =  4 indeks =  0
# [1, 3, 0, 4, 8, 11]

# %%
# data = [8, 3, 0, 11, 4, 1, 3, 5 , 9, 32, 42, 23,32, 67]
# for j in range(len(data)-1, 0, -1):
#     print('iterasi', j)
#     maks =data[0]
#     idMaks=0
#     for i in range(1, j):
#         print(maks, ' < ', data[i])
#         if maks < data[i]:
#             maks=data[i]
#             idMaks = i
#     print('Nilai maks = ', maks, 'indeks = ', idMaks)
#     # data[-1], data[idMaks] = data[idMaks], data[-1]
#     data[idMaks]=data[j]
#     data[j] = maks
#     print(data)

# %%
data = [8, 3, 4, 5, 2, 6, 3, 9, 4]
for iterasi in range(len(data)-1):
    print('iterasi', iterasi)
    maks=data[0]
    idMaks=0
    print('data awal', data)
    for i in range(1, len(data)-iterasi):
        print(maks, '<', data[i])
        if maks < data[i]:
            maks=data[i]
            idMaks=i
    print('MAks', maks,'IDmaKS', idMaks)
    data[idMaks]=data[len(data)-(iterasi+1)]
    data[len(data)-(iterasi+1)]=maks
    print(data)
# Out:
# iterasi 0
# data awal [8, 3, 4, 5, 2, 6, 3, 9, 4]
# 8 < 3
# 8 < 4
# 8 < 5
# 8 < 2
# 8 < 6
# 8 < 3
# 8 < 9
# 9 < 4
# MAks 9 IDmaKS 7
# [8, 3, 4, 5, 2, 6, 3, 4, 9]
# iterasi 1
# data awal [8, 3, 4, 5, 2, 6, 3, 4, 9]
# 8 < 3
# 8 < 4
# 8 < 5
# 8 < 2
# 8 < 6
# 8 < 3
# 8 < 4
# MAks 8 IDmaKS 0
# [4, 3, 4, 5, 2, 6, 3, 8, 9]
# iterasi 2
# data awal [4, 3, 4, 5, 2, 6, 3, 8, 9]
# 4 < 3
# 4 < 4
# 4 < 5
# 5 < 2
# 5 < 6
# 6 < 3
# MAks 6 IDmaKS 5
# [4, 3, 4, 5, 2, 3, 6, 8, 9]
# iterasi 3
# data awal [4, 3, 4, 5, 2, 3, 6, 8, 9]
# 4 < 3
# 4 < 4
# 4 < 5
# 5 < 2
# 5 < 3
# MAks 5 IDmaKS 3
# [4, 3, 4, 3, 2, 5, 6, 8, 9]
# iterasi 4
# data awal [4, 3, 4, 3, 2, 5, 6, 8, 9]
# 4 < 3
# 4 < 4
# 4 < 3
# 4 < 2
# MAks 4 IDmaKS 0
# [2, 3, 4, 3, 4, 5, 6, 8, 9]
# iterasi 5
# data awal [2, 3, 4, 3, 4, 5, 6, 8, 9]
# 2 < 3
# 3 < 4
# 4 < 3
# MAks 4 IDmaKS 2
# [2, 3, 3, 4, 4, 5, 6, 8, 9]
# iterasi 6
# data awal [2, 3, 3, 4, 4, 5, 6, 8, 9]
# 2 < 3
# 3 < 3
# MAks 3 IDmaKS 1
# [2, 3, 3, 4, 4, 5, 6, 8, 9]
# iterasi 7
# ...
