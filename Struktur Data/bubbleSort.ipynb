# %%
def bubbleSort(listData):
    print('Data yang akan diurutkan : ', listData)
    count=0
    for outIter in range(len(listData)-1,-1,-1):
        print('outIter=',outIter)
        count=count+1
        print ('Iterasi ke-', count,':')
        for i in range(outIter):
            if listData[i]>listData[i+1]:
                temp=listData[i]
                listData[i]=listData[i+1]
                listData[i+1]=temp
                #listData[i],listData[i+1]=listData[i+1],listData[i]
            print(outIter,'=',listData)
    print('Data urut-',listData)

# %%
a=[12,0,5,1,11,20,4,2]
bubbleSort(a)
b=[12,11,5,1,0]
print('--')
bubbleSort(b)
# Out:
# Data yang akan diurutkan :  [12, 0, 5, 1, 11, 20, 4, 2]
# outIter= 7
# Iterasi ke- 1 :
# 7 = [0, 12, 5, 1, 11, 20, 4, 2]
# 7 = [0, 5, 12, 1, 11, 20, 4, 2]
# 7 = [0, 5, 1, 12, 11, 20, 4, 2]
# 7 = [0, 5, 1, 11, 12, 20, 4, 2]
# 7 = [0, 5, 1, 11, 12, 20, 4, 2]
# 7 = [0, 5, 1, 11, 12, 4, 20, 2]
# 7 = [0, 5, 1, 11, 12, 4, 2, 20]
# outIter= 6
# Iterasi ke- 2 :
# 6 = [0, 5, 1, 11, 12, 4, 2, 20]
# 6 = [0, 1, 5, 11, 12, 4, 2, 20]
# 6 = [0, 1, 5, 11, 12, 4, 2, 20]
# 6 = [0, 1, 5, 11, 12, 4, 2, 20]
# 6 = [0, 1, 5, 11, 4, 12, 2, 20]
# 6 = [0, 1, 5, 11, 4, 2, 12, 20]
# outIter= 5
# Iterasi ke- 3 :
# 5 = [0, 1, 5, 11, 4, 2, 12, 20]
# 5 = [0, 1, 5, 11, 4, 2, 12, 20]
# 5 = [0, 1, 5, 11, 4, 2, 12, 20]
# 5 = [0, 1, 5, 4, 11, 2, 12, 20]
# 5 = [0, 1, 5, 4, 2, 11, 12, 20]
# outIter= 4
# Iterasi ke- 4 :
# 4 = [0, 1, 5, 4, 2, 11, 12, 20]
# 4 = [0, 1, 5, 4, 2, 11, 12, 20]
# 4 = [0, 1, 4, 5, 2, 11, 12, 20]
# 4 = [0, 1, 4, 2, 5, 11, 12, 20]
# outIter= 3
# Iterasi ke- 5 :
# 3 = [0, 1, 4, 2, 5, 11, 12, 20]
# ...

# %%
datalist = [11, 5, 7, 13, 2]
count = 1
print(datalist)
for i in range(len(datalist)-1):
    if datalist[i]>datalist[i+1]:
        datalist[i],datalist[i+1]=datalist[i+1],datalist[i]
    print(count, ':', datalist)
    count+=1
print()
count = 1

for i in range(3):
    if datalist[i]>datalist[i+1]:
        datalist[i],datalist[i+1]=datalist[i+1],datalist[i]
    print(count, ':', datalist)
    count+=1
count =1
print()
for i in range(2):
    if datalist[i]>datalist[i+1]:
        datalist[i],datalist[i+1]=datalist[i+1],datalist[i]
    print(count, ':', datalist)
    count+=1
count =1
print()
for i in range(1):
    if datalist[i]>datalist[i+1]:
        datalist[i],datalist[i+1]=datalist[i+1],datalist[i]
    print(count, ':', datalist)
    count+=1
# Out:
# [11, 5, 7, 13, 2]
# 1 : [5, 11, 7, 13, 2]
# 2 : [5, 7, 11, 13, 2]
# 3 : [5, 7, 11, 13, 2]
# 4 : [5, 7, 11, 2, 13]
#
# 1 : [5, 7, 11, 2, 13]
# 2 : [5, 7, 11, 2, 13]
# 3 : [5, 7, 2, 11, 13]
#
# 1 : [5, 7, 2, 11, 13]
# 2 : [5, 2, 7, 11, 13]
#
# 1 : [2, 5, 7, 11, 13]

# %%
datalist = [11, 5,7, 4, 8, 6, 1, 12, 15, 11, 7, 13, 2]

for iter in range(len(datalist)-1, 0, -1):
    count = 1
    print('iter', iter)
    for i in range(iter):
        if datalist[i]>datalist[i+1]:
            datalist[i],datalist[i+1]=datalist[i+1],datalist[i]
        print(count, ':', datalist)
        count+=1
    print()
# Out:
# iter 12
# 1 : [5, 11, 7, 4, 8, 6, 1, 12, 15, 11, 7, 13, 2]
# 2 : [5, 7, 11, 4, 8, 6, 1, 12, 15, 11, 7, 13, 2]
# 3 : [5, 7, 4, 11, 8, 6, 1, 12, 15, 11, 7, 13, 2]
# 4 : [5, 7, 4, 8, 11, 6, 1, 12, 15, 11, 7, 13, 2]
# 5 : [5, 7, 4, 8, 6, 11, 1, 12, 15, 11, 7, 13, 2]
# 6 : [5, 7, 4, 8, 6, 1, 11, 12, 15, 11, 7, 13, 2]
# 7 : [5, 7, 4, 8, 6, 1, 11, 12, 15, 11, 7, 13, 2]
# 8 : [5, 7, 4, 8, 6, 1, 11, 12, 15, 11, 7, 13, 2]
# 9 : [5, 7, 4, 8, 6, 1, 11, 12, 11, 15, 7, 13, 2]
# 10 : [5, 7, 4, 8, 6, 1, 11, 12, 11, 7, 15, 13, 2]
# 11 : [5, 7, 4, 8, 6, 1, 11, 12, 11, 7, 13, 15, 2]
# 12 : [5, 7, 4, 8, 6, 1, 11, 12, 11, 7, 13, 2, 15]
#
# iter 11
# 1 : [5, 7, 4, 8, 6, 1, 11, 12, 11, 7, 13, 2, 15]
# 2 : [5, 4, 7, 8, 6, 1, 11, 12, 11, 7, 13, 2, 15]
# 3 : [5, 4, 7, 8, 6, 1, 11, 12, 11, 7, 13, 2, 15]
# 4 : [5, 4, 7, 6, 8, 1, 11, 12, 11, 7, 13, 2, 15]
# 5 : [5, 4, 7, 6, 1, 8, 11, 12, 11, 7, 13, 2, 15]
# 6 : [5, 4, 7, 6, 1, 8, 11, 12, 11, 7, 13, 2, 15]
# 7 : [5, 4, 7, 6, 1, 8, 11, 12, 11, 7, 13, 2, 15]
# ...
